# %% [markdown]
# # Experiment on replicating `Modeling rain-driven overland flow`
# The goal is to simulate rain accumulating on a surface and flowing, using the Poiseuille friction model which the [paper](https://arxiv.org/pdf/1609.04711) found most suitable for these conditions.

# %% [markdown]
# 1. Geometry = a tilted rectangle, not a basin

# %%
from ngsolve import *
from netgen.occ import *
from ngsolve.webgui import *
from ngsolve.webgui import Draw
import numpy as np


L  = 4.04 # flume length  [m]
W  = 0.115 # flume width   [m]
SlopeDeg = 5 # (%)  ➔  2 %  ⇒ 0.02
S0   = SlopeDeg/100 # tan α  (positive downslope)

# create a flat rectangle; the slope only appears in the source term
geo = Rectangle(L,W).Face()
geo.edges.Min(X).name="inlet"
geo.edges.Max(X).name="outlet"
geo.edges.Min(Y).name = "wall"
geo.edges.Max(Y).name = "wall"
geo = OCCGeometry(geo, dim=2)
mesh = Mesh(geo.GenerateMesh(maxh=0.05))
# mesh.Curve(3)
Draw(mesh)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.25…
# BaseWebGuiScene

# %% [markdown]
# 2. Unknowns, rainfall source and friction law

# %%
order = 2
fes   = L2(mesh,order=order)**3 # (h, h u, h v)

U,V = fes.TnT() # "Trial" and "Test" function
h, hu, hv = U

g  = 9.81 # [m/s²]
nu = 1e-6 # kinematic viscosity of water  [m²/s]
I_mm_h = 250 # rainfall intensity [mm h⁻¹]
R = I_mm_h/1000/3600 # convert to m s⁻¹  (≈ 6.94 × 10⁻⁶)
eps = 1e-6

# %%
min_h_friction = 1e-6 # Minimum water depth for friction denominator (can be tuned)

def Sf_poiseuille(U_components_cf):
    h_cf, hu_cf, hv_cf = U_components_cf # These are CoefficientFunctions

    # Regularize h to avoid division by zero or very small numbers
    h_regularized = Max(h_cf, min_h_friction)

    # Calculate S_f components, assuming hu_cf is flux qx = h*u, hv_cf is flux qy = h*v
    # Sf = (3*nu/g) * (q / h_reg^3)
    S_f_x = (3 * nu / g) * (hu_cf / h_regularized**3)
    S_f_y = (3 * nu / g) * (hv_cf / h_regularized**3) # If your model is 1D in x, hv_cf might be 0

    return CF((S_f_x, S_f_y))

# %%
n = specialcf.normal(mesh.dim)
def Max(a, b):
    """point-wise maximum for CoefficientFunctions"""
    return IfPos(a-b, a, b)

# %%
def F(U):
    h, hvx, hvy = U
    vx = hvx/h
    vy = hvy/h
    return CF(((hvx,hvy),
               (hvx*vx + 0.5*g*h**2, hvx*vy),
               (hvx*vy, hvy*vy + 0.5*g*h**2)),dims=(3,2))

# %%
n = specialcf.normal(mesh.dim)
def Max(u,v):
    return IfPos(u-v,u,v)
def Fmax(A,B): # max. characteristic speed:
    ha, hua, hva = A
    hb, hub, hvb = B
    vnorma = sqrt(hua**2+hva**2)/ha
    vnormb = sqrt(hub**2+hvb**2)/hb
    return Max(vnorma+sqrt(g*A[0]),vnormb+sqrt(g*B[0]))

def Fhatn(U): # numerical flux
    Uhat = U.Other(bnd=Ubnd)
    return (0.5*F(U)+0.5*F(Uhat))*n + Fmax(U,Uhat)/2*(U-Uhat)

# %%
U0 = CF((eps, 0, 0))
Ubnd = CF((h, -hu, -hv))

# %%
print(F(U).shape)
print(F(U).trans.shape)
print(Grad(V).shape)
print(Grad(V).trans.shape)
# Out:
# (3, 2)
# (2, 3)
# (3, 2)
# (2, 3)

# %% [markdown]
# 3. DG bilinear plus source terms (rain, bed-slope, friction)

# %%
def DGBilinearForm(fes,F,Fhatnd, Ubnd):
    a = BilinearForm(fes, nonassemble=True)
    a += - InnerProduct(F(U),Grad(V)) * dx
    a += InnerProduct(Fhatn(U),V) * dx(element_boundary=True)
    return a

a = DGBilinearForm(fes,F,Fhatn, Ubnd)

# %%
from DGdiffusion import AddArtificialDiffusion

artvisc = Parameter(1.0)
if order > 0:
    AddArtificialDiffusion(a,Ubnd,artvisc,compile=True)

# %%
invMA = fes.Mass(1).Inverse() @ a.mat

# %%
gfu = GridFunction(fes)
gfu.Set(U0)

gfh, gfhu, gfhv = gfu

min_depth = 1e-5
gfvu = IfPos(gfh - min_depth, gfhu/gfh, 0)
gfvv = IfPos(gfh - min_depth, gfhv/gfh, 0)

momentum = CF((gfhu, gfhv))
velocity = CF((gfvu, gfvv))

scenes = [ 
    Draw(momentum, mesh, "mom"),
    Draw(velocity, mesh, "vel"),
    Draw(gfh, mesh, "h") 
]
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.25…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.25…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.25…

# %%
def Source(gfu):
    h  = gfu.components[0]
    hu = gfu.components[1]
    hv = gfu.components[2]

    min_depth = 1e-5
    vx = IfPos(h - min_depth, hu/h, 0)
    vy = IfPos(h - min_depth, hv/h, 0)

    # Rainfall contribution:  (R, 0, 0)
    srain_h  = R
    srain_hu = 0
    srain_hv = 0

    # Bed-slope contribution:  +g h S₀ (gravity-driven along x-direction)
    sslope_hu = g * h * S0
    sslope_hv = 0

    # Friction contribution (Poiseuille friction):
    friction = Sf_poiseuille((h, hu, hv))
    sfx = friction[0]
    sfy = friction[1]

    return CF( ( srain_h,
                 srain_hu + sslope_hu + sfx,
                 srain_hv + sslope_hv + sfy ) )

# %% [markdown]
# 4. Time integrator

# %%
def TimeLoop(a, gfu, dt, T, Source, nsamplings=100, scenes=scenes,
             multidim_draw=False, md_nsamplings=20):
    if multidim_draw:
        gfu_t = GridFunction(gfu.space, multidim=True)
    res = gfu.vec.CreateVector()
    fes = a.space
    t = 0; i = 0
    nsteps = int(ceil(T / dt))
    invma = fes.Mass(1).Inverse() @ a.mat

    if multidim_draw:
        gfu_t.AddMultiDimComponent(gfu.vec)
    mass_inv = fes.Mass(1).Inverse()
    log_interval = 50
    max_h_threshold = 1.0
    with TaskManager():
        while t <= T - 0.5 * dt:
            res.data = invma * gfu.vec
            lf_source = LinearForm(fes)
            lf_source += InnerProduct(Source(gfu), fes.TestFunction()) * dx
            lf_source.Assemble()
            source_term = mass_inv * lf_source.vec
            res.data -= source_term
            gfu.vec.data -= dt * res
            t += dt
            if (i + 1) % max(int(nsteps / nsamplings), 1) == 0:
                for s in scenes:
                    s.Redraw()
            if (i + 1) % log_interval == 0:
                h_coeffs = gfu.components[0].vec.FV().NumPy()
                hu_coeffs = gfu.components[1].vec.FV().NumPy()
                hv_coeffs = gfu.components[2].vec.FV().NumPy() 
                print(f"\nStep: {i+1}, Time: {t:.6f}")
                print(f"  h min: {np.min(h_coeffs):.3e}, h max: {np.max(h_coeffs):.3e}")
                print(f"  hu min: {np.min(hu_coeffs):.3e}, hu max: {np.max(hu_coeffs):.3e}")
                # print(f"  hv min: {np.min(hv_coeffs):.3e}, hv max: {np.max(hv_coeffs):.3e}") # Uncomment if hv is used
                   
            if multidim_draw and (i + 1) % max(int(nsteps / md_nsamplings), 1) == 0:
                gfu_t.AddMultiDimComponent(gfu.vec)
            i += 1
            print("\rt = {:.6f}".format(t), end="")
    for s in scenes:
        s.Redraw()
    if multidim_draw:
        return gfu_t
gfu.Set(U0)
dt = 0.0025
T = 15

# %%
with TaskManager():
    gfu_t = TimeLoop(a, gfu, dt=dt, T=T, Source=Source, multidim_draw=True, md_nsamplings=5)
# Out:
# t = 0.122500
# Step: 50, Time: 0.125000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 0.247500
# Step: 100, Time: 0.250000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 0.372500
# Step: 150, Time: 0.375000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 0.497500
# Step: 200, Time: 0.500000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 0.622500
# Step: 250, Time: 0.625000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 0.747500
# Step: 300, Time: 0.750000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 0.872500
# Step: 350, Time: 0.875000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 0.997500
# Step: 400, Time: 1.000000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 1.122500
# Step: 450, Time: 1.125000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 1.247500
# Step: 500, Time: 1.250000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 1.372500
# Step: 550, Time: 1.375000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 1.497500
# Step: 600, Time: 1.500000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 1.622500
# Step: 650, Time: 1.625000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 1.747500
# Step: 700, Time: 1.750000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 1.872500
# Step: 750, Time: 1.875000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 1.997500
# Step: 800, Time: 2.000000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 2.122500
# Step: 850, Time: 2.125000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 2.247500
# Step: 900, Time: 2.250000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 2.372500
# Step: 950, Time: 2.375000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 2.497500
# Step: 1000, Time: 2.500000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 2.622500
# Step: 1050, Time: 2.625000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 2.747500
# Step: 1100, Time: 2.750000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 2.872500
# Step: 1150, Time: 2.875000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 2.997500
# Step: 1200, Time: 3.000000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 3.122500
# Step: 1250, Time: 3.125000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 3.247500
# Step: 1300, Time: 3.250000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 3.372500
# Step: 1350, Time: 3.375000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 3.497500
# Step: 1400, Time: 3.500000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 3.622500
# Step: 1450, Time: 3.625000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 3.747500
# Step: 1500, Time: 3.750000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 3.872500
# Step: 1550, Time: 3.875000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 3.997500
# Step: 1600, Time: 4.000000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 4.122500
# Step: 1650, Time: 4.125000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 4.247500
# Step: 1700, Time: 4.250000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 4.372500
# Step: 1750, Time: 4.375000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 4.497500
# Step: 1800, Time: 4.500000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 4.622500
# Step: 1850, Time: 4.625000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 4.747500
# Step: 1900, Time: 4.750000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 4.872500
# Step: 1950, Time: 4.875000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 4.997500
# Step: 2000, Time: 5.000000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 5.015000
# no more timer available (lff_from_py), reusing last one
# t = 5.122500
# Step: 2050, Time: 5.125000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 5.247500
# Step: 2100, Time: 5.250000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 5.372500
# Step: 2150, Time: 5.375000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 5.497500
# Step: 2200, Time: 5.500000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 5.622500
# Step: 2250, Time: 5.625000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 5.747500
# Step: 2300, Time: 5.750000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 5.872500
# Step: 2350, Time: 5.875000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 5.997500
# Step: 2400, Time: 6.000000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 6.122500
# Step: 2450, Time: 6.125000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 6.247500
# Step: 2500, Time: 6.250000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 6.372500
# Step: 2550, Time: 6.375000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 6.497500
# Step: 2600, Time: 6.500000
#   h min: nan, h max: nan
#   hu min: nan, hu max: nan
# t = 6